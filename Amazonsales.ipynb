# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv("sales.csv")

print(df)
# Out:
#      Order_ID Customer_Name  Gender  Age    City Product_Category  Quantity  \
# 0        1001           NaN       F   22  mumbai       electronic       1.0
# 1        1002         Pooja       m  120     NaN         Clothing       4.0
# 2        1003        Anjali    Male   21     NaN      Electronics       3.0
# 3        1004         Vikas  Female  120   Delhi       electronic       3.0
# 4        1005         Akash       F   45     NaN        Furniture       4.0
# ..        ...           ...     ...  ...     ...              ...       ...
# 610      1011         Vikas       M   39  mumbai       electronic       3.0
# 611      1012         Rohit       f  120    PUNE         Clothing       5.0
# 612      1013         Pooja       m  120  Mumbai       electronic       3.0
# 613      1014         Kiran       m   20  mumbai          Clothng       1.0
# 614      1015         Rohit  Female  120    PUNE         Clothing       NaN
#
#       Price  Order_Date Payment_Method  Rating
# 0       abc  05-01-2024            UPI     1.0
# 1     67000  13-04-2024            UPI     2.0
# 2       NaN  18-03-2024           Card     1.0
# 3     45000  31-03-2024            UPI     1.0
# 4       NaN  21-01-2024           Card     3.0
# ..      ...         ...            ...     ...
# 610     NaN  15-01-2024           Card     4.0
# 611    1500  21-04-2024           Card     NaN
# 612  999999  03-01-2024            UPI     3.0
# 613   25000  17-01-2024           cash     5.0
# 614   67000  21-02-2024           Card     4.0
#
# [615 rows x 11 columns]

# %%
print(df.head())
# Out:
#    Order_ID Customer_Name  Gender  Age    City Product_Category  Quantity  \
# 0      1001           NaN       F   22  mumbai       electronic       1.0
# 1      1002         Pooja       m  120     NaN         Clothing       4.0
# 2      1003        Anjali    Male   21     NaN      Electronics       3.0
# 3      1004         Vikas  Female  120   Delhi       electronic       3.0
# 4      1005         Akash       F   45     NaN        Furniture       4.0
#
#    Price  Order_Date Payment_Method  Rating
# 0    abc  05-01-2024            UPI     1.0
# 1  67000  13-04-2024            UPI     2.0
# 2    NaN  18-03-2024           Card     1.0
# 3  45000  31-03-2024            UPI     1.0
# 4    NaN  21-01-2024           Card     3.0

# %%
print(df.shape)
# Out:
# (615, 11)

# %%
print(df.columns)
# Out:
# Index(['Order_ID', 'Customer_Name', 'Gender', 'Age', 'City',
#        'Product_Category', 'Quantity', 'Price', 'Order_Date', 'Payment_Method',
#        'Rating'],
#       dtype='str')

# %%
print(df.describe())
# Out:
#           Order_ID    Quantity      Rating
# count   615.000000  515.000000  514.000000
# mean   1293.365854    2.924272    3.052529
# std     177.074823    1.456267    1.442587
# min    1001.000000    1.000000    1.000000
# 25%    1139.500000    2.000000    2.000000
# 50%    1293.000000    3.000000    3.000000
# 75%    1446.500000    4.000000    4.000000
# max    1600.000000    5.000000    5.000000

# %%
print(df["Age"].unique())
# Out:
# <StringArray>
# [    '22',    '120',     '21',     '45',     '38', 'twenty',     '-3',
#       nan,     '39',     '20',     '24',     '25',     '42',     '26',
#      '18',     '37',     '32',     '40',     '36',     '30',     '41',
#      '44',     '27',     '23',     '43',     '29',     '33',     '28',
#      '19',     '35',     '34']
# Length: 31, dtype: str

# %%
df["Age"] = pd.to_numeric(df["Age"], errors="coerce")
print(df["Age"].unique())
# Out:
# [ 22. 120.  21.  45.  38.  nan  -3.  39.  20.  24.  25.  42.  26.  18.
#   37.  32.  40.  36.  30.  41.  44.  27.  23.  43.  29.  33.  28.  19.
#   35.  34.]

# %%
print(df["Age"])
# Out:
# 0       22.0
# 1      120.0
# 2       21.0
# 3      120.0
# 4       45.0
#        ...
# 610     39.0
# 611    120.0
# 612    120.0
# 613     20.0
# 614    120.0
# Name: Age, Length: 615, dtype: float64

# %%
df["Age"] = df["Age"].fillna(0)

# %%
#Numpy 
arr = np.array(df["Age"])

print(np.max(arr))
print(np.min(arr))
print(np.sum(arr))
# Out:
# 120.0
# -3.0
# 18110.0

# %%
print(df["Age"].sort_values())
# Out:
# 608     -3.0
# 578     -3.0
# 585     -3.0
# 591     -3.0
# 44      -3.0
#        ...
# 611    120.0
# 612    120.0
# 3      120.0
# 614    120.0
# 1      120.0
# Name: Age, Length: 589, dtype: float64

# %%
print(df[df["Age"] > 100])
# Out:
#      Order_ID Customer_Name  Gender    Age    City Product_Category  Quantity  \
# 1        1002         Pooja       m  120.0     NaN         Clothing       4.0
# 3        1004         Vikas  Female  120.0   Delhi       electronic       3.0
# 11       1012         Rohit       f  120.0    PUNE         Clothing       5.0
# 12       1013         Pooja       m  120.0  Mumbai       electronic       3.0
# 14       1015         Rohit  Female  120.0    PUNE         Clothing       NaN
# ..        ...           ...     ...    ...     ...              ...       ...
# 601      1002         Pooja       m  120.0     NaN         Clothing       4.0
# 603      1004         Vikas  Female  120.0   Delhi       electronic       3.0
# 611      1012         Rohit       f  120.0    PUNE         Clothing       5.0
# 612      1013         Pooja       m  120.0  Mumbai       electronic       3.0
# 614      1015         Rohit  Female  120.0    PUNE         Clothing       NaN
#
#       Price  Order_Date Payment_Method  Rating
# 1     67000  13-04-2024            UPI     2.0
# 3     45000  31-03-2024            UPI     1.0
# 11     1500  21-04-2024           Card     NaN
# 12   999999  03-01-2024            UPI     3.0
# 14    67000  21-02-2024           Card     4.0
# ..      ...         ...            ...     ...
# 601   67000  13-04-2024            UPI     2.0
# 603   45000  31-03-2024            UPI     1.0
# 611    1500  21-04-2024           Card     NaN
# 612  999999  03-01-2024            UPI     3.0
# 614   67000  21-02-2024           Card     4.0
#
# [122 rows x 11 columns]
#      Order_ID Customer_Name  Gender  Age     City Product_Category  Quantity  \
# 8        1009         Akash       f -3.0   Nagpur          Clothng       3.0
# 18       1019         Rahul       M -3.0   mumbai        Furniture       1.0
# 20       1021         Sneha       F -3.0      NaN         Clothing       4.0
# 21       1022            Om  Female -3.0   mumbai       electronic       NaN
# 28       1029          Riya    Male -3.0    Delhi      Electronics       1.0
# ..        ...           ...     ...  ...      ...              ...       ...
# 578      1579         Sneha       M -3.0     Pune        Furniture       1.0
# 585      1586         Rohit       M -3.0     PUNE         Clothing       4.0
# 591      1592        Anjali       f -3.0     Pune       electronic       5.0
# 596      1597         Priya       f -3.0   mumbai      Electronics       3.0
# 608      1009         Akash       f -3.0   Nagpur          Clothng       3.0
#
#       Price  Order_Date Payment_Method  Rating
# 8     45000  18-01-2024           card     4.0
# 18    45000  25-01-2024           Cash     5.0
# 20      500  22-01-2024           cash     1.0
# 21   999999  20-01-2024           Cash     3.0
# 28      abc  16-04-2024           Card     1.0
# ..      ...         ...            ...     ...
# 578    1500  22-01-2024           Card     1.0
# 585     NaN  20-01-2024            UPI     NaN
# 591    1500  19-01-2024           Cash     3.0
# 596     500  18-04-2024           Card     2.0
# 608   45000  18-01-2024           card     4.0
#
# [130 rows x 11 columns]

# %%
print(df[df["Age"] < 0])
# Out:
#      Order_ID Customer_Name  Gender  Age     City Product_Category  Quantity  \
# 8        1009         Akash       f -3.0   Nagpur          Clothng       3.0
# 18       1019         Rahul       M -3.0   mumbai        Furniture       1.0
# 20       1021         Sneha       F -3.0      NaN         Clothing       4.0
# 21       1022            Om  Female -3.0   mumbai       electronic       NaN
# 28       1029          Riya    Male -3.0    Delhi      Electronics       1.0
# ..        ...           ...     ...  ...      ...              ...       ...
# 578      1579         Sneha       M -3.0     Pune        Furniture       1.0
# 585      1586         Rohit       M -3.0     PUNE         Clothing       4.0
# 591      1592        Anjali       f -3.0     Pune       electronic       5.0
# 596      1597         Priya       f -3.0   mumbai      Electronics       3.0
# 608      1009         Akash       f -3.0   Nagpur          Clothng       3.0
#
#       Price  Order_Date Payment_Method  Rating
# 8     45000  18-01-2024           card     4.0
# 18    45000  25-01-2024           Cash     5.0
# 20      500  22-01-2024           cash     1.0
# 21   999999  20-01-2024           Cash     3.0
# 28      abc  16-04-2024           Card     1.0
# ..      ...         ...            ...     ...
# 578    1500  22-01-2024           Card     1.0
# 585     NaN  20-01-2024            UPI     NaN
# 591    1500  19-01-2024           Cash     3.0
# 596     500  18-04-2024           Card     2.0
# 608   45000  18-01-2024           card     4.0
#
# [130 rows x 11 columns]

# %%
df = df[(df["Age"] >= 1) & (df["Age"] <= 100)]

# %%
print(df["Age"].describe())
# Out:
# count    119.000000
# mean      32.436975
# std        8.647169
# min       18.000000
# 25%       24.500000
# 50%       33.000000
# 75%       40.000000
# max       45.000000
# Name: Age, dtype: float64

# %%
#print(df["City"])
print(df["Customer_Name"].unique())
# Out:
# <StringArray>
# [     'Pooja',      'Vikas',      'Kiran',      'Priya',       'Neha',
#          'Om',   'Harshada',      'Rahul',      'Akash',     'Sameer',
#       'Sneha',     'Anjali',      'Meena',       'Riya',       'Amit',
#       'Rohit',     ' Neha ',    ' Rahul ',    ' Priya ', ' Harshada ',
#     ' Kiran ',    ' Rohit ',    ' Vikas ']
# Length: 23, dtype: str

# %%
print(df["City"].isnull().sum())
# Out:
# 18

# %%
df = df.dropna(subset=["City"])

# %%
df["City"] = df["City"].str.title()

# %%
print(df["City"].value_counts())
# Out:
# City
# Pune       42
# Mumbai     38
# Delhi      11
#  Nagpur    10
# Name: count, dtype: int64

# %%
df["City"].value_counts().plot(kind="bar")

plt.title("City Distribution")
plt.xlabel("City")
plt.ylabel("Count")

plt.show()

# %%
print(df.columns)
# Out:
# Index(['Order_ID', 'Customer_Name', 'Gender', 'Age', 'City',
#        'Product_Category', 'Quantity', 'Price', 'Order_Date', 'Payment_Method',
#        'Rating'],
#       dtype='str')

# %%
print(df["Rating"])
# Out:
# 5      4.0
# 13     5.0
# 25     2.0
# 27     2.0
# 42     4.0
#       ...
# 584    5.0
# 594    4.0
# 595    5.0
# 605    4.0
# 613    5.0
# Name: Rating, Length: 70, dtype: float64

# %%
#print(df["Order_Date"])

df["Order_Date"] = pd.to_datetime(df["Order_Date"], format="%d-%m-%Y")
print(df["Order_Date"].dtype)
# Out:
# datetime64[us]

# %%
df["Month"] = df["Order_Date"].dt.month
df["Year"] = df["Order_Date"].dt.year
df["Day"] = df["Order_Date"].dt.day

# %%
df["Sales"] = df["Quantity"] * df["Price"]

# %%
monthly_sales = df.groupby("Month")["Sales"].sum()

plt.figure(figsize=(8,5))
plt.plot(monthly_sales.index, monthly_sales.values)

plt.title("Monthly Sales")
plt.xlabel("Month")
plt.ylabel("Sales")

plt.show()

# %%
df["Price"] = pd.to_numeric(df["Price"], errors="coerce")
print(df["Price"])
print(df.dtypes)
# Out:
# 5       45000.0
# 13      25000.0
# 25       1500.0
# 27      67000.0
# 42      25000.0
#          ...
# 584     25000.0
# 594    999999.0
# 595      1500.0
# 605     45000.0
# 613     25000.0
# Name: Price, Length: 70, dtype: float64
# Order_ID                     int64
# Customer_Name                  str
# Gender                         str
# Age                        float64
# City                           str
# Product_Category               str
# Quantity                   float64
# Price                      float64
# Order_Date          datetime64[us]
# Payment_Method                 str
# Rating                     float64
# Month                        int32
# Year                         int32
# Day                          int32
# Sales                      float64
# dtype: object

# %%
print(df["Price"].isnull().sum())
df["Price"] = df["Price"].fillna(0)

print(df["Price"].mean())
print(df["Price"].max())
# Out:
# 0
# 195856.9714285714
# 999999.0

# %%
df["Gender"] = df["Gender"].replace({
    "M": "Male",
    "m": "Male",
    "F": "Female",
    "f": "Female"
})
df.Gender
# Out:
# 0      Female
# 1        Male
# 2        Male
# 3      Female
# 4      Female
#         ...
# 610      Male
# 611    Female
# 612      Male
# 613      Male
# 614    Female
# Name: Gender, Length: 615, dtype: str

# %%
df["Age"] = pd.to_numeric(df["Age"], errors="coerce")

# %%
df = df[(df["Age"] >= 0) & (df["Age"] <= 100)]

# %%
df["Age"].describe()
# Out:
# count    126.000000
# mean      32.420635
# std        8.770271
# min       18.000000
# 25%       24.000000
# 50%       33.000000
# 75%       40.000000
# max       45.000000
# Name: Age, dtype: float64

# %%
print(df["Gender"].unique())
# Out:
# <StringArray>
# ['Male', 'Female']
# Length: 2, dtype: str

# %%
df.isnull().sum()
df = df.dropna(subset=['Customer_Name'])

# %%
df['Gender'] = df['Gender'].str.upper()

df['Gender'] = df['Gender'].replace({
    'M': 'Male',
    'F': 'Female'
})

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'], format='%d-%m-%Y')

# %%
df.dtypes
# Out:
# Order_ID                     int64
# Customer_Name                  str
# Gender                         str
# Age                            str
# City                           str
# Product_Category               str
# Quantity                   float64
# Price                      float64
# Order_Date          datetime64[us]
# Payment_Method                 str
# Rating                     float64
# Total_Amount               float64
# Month                        int32
# Day                          int32
# dtype: object

# %%
df['Price'] = df['Price'].replace('[₹,]', '', regex=True)
df['Price'] = pd.to_numeric(df['Price'], errors='coerce')
df.dtypes
# Out:
# Order_ID                     int64
# Customer_Name                  str
# Gender                         str
# Age                            str
# City                           str
# Product_Category               str
# Quantity                   float64
# Price                      float64
# Order_Date          datetime64[us]
# Payment_Method                 str
# Rating                     float64
# dtype: object

# %%
df['Total_Amount'] = df['Price'] * df['Quantity']

df['Month'] = df['Order_Date'].dt.month
df['Day'] = df['Order_Date'].dt.day
df
# Out:
#      Order_ID Customer_Name  Gender  Age     City Product_Category  Quantity  \
# 1        1002         Pooja    MALE  120      NaN         Clothing       4.0
# 2        1003        Anjali    MALE   21      NaN      Electronics       3.0
# 3        1004         Vikas  FEMALE  120    Delhi       electronic       3.0
# 4        1005         Akash  FEMALE   45      NaN        Furniture       4.0
# 5        1006         Pooja  FEMALE   38   Nagpur         Clothing       5.0
# ..        ...           ...     ...  ...      ...              ...       ...
# 610      1011         Vikas    MALE   39   mumbai       electronic       3.0
# 611      1012         Rohit  FEMALE  120     PUNE         Clothing       5.0
# 612      1013         Pooja    MALE  120   Mumbai       electronic       3.0
# 613      1014         Kiran    MALE   20   mumbai          Clothng       1.0
# 614      1015         Rohit  FEMALE  120     PUNE         Clothing       NaN
#
#         Price Order_Date Payment_Method  Rating  Total_Amount  Month  Day
# 1     67000.0 2024-04-13            UPI     2.0      268000.0      4   13
# 2         NaN 2024-03-18           Card     1.0           NaN      3   18
# 3     45000.0 2024-03-31            UPI     1.0      135000.0      3   31
# 4         NaN 2024-01-21           Card     3.0           NaN      1   21
# 5     45000.0 2024-01-21           cash     4.0      225000.0      1   21
# ..        ...        ...            ...     ...           ...    ...  ...
# 610       NaN 2024-01-15           Card     4.0           NaN      1   15
# 611    1500.0 2024-04-21           Card     NaN        7500.0      4   21
# 612  999999.0 2024-01-03            UPI     3.0     2999997.0      1    3
# 613   25000.0 2024-01-17           cash     5.0       25000.0      1   17
# 614   67000.0 2024-02-21           Card     4.0           NaN      2   21
#
# [589 rows x 14 columns]

# %%
df.drop_duplicates()
# Out:
#      Order_ID Customer_Name  Gender     Age     City Product_Category  \
# 1        1002         Pooja    MALE     120      NaN         Clothing
# 2        1003        Anjali    MALE      21      NaN      Electronics
# 3        1004         Vikas  FEMALE     120    Delhi       electronic
# 4        1005         Akash  FEMALE      45      NaN        Furniture
# 5        1006         Pooja  FEMALE      38   Nagpur         Clothing
# ..        ...           ...     ...     ...      ...              ...
# 595      1596         Rohit  FEMALE      18     PUNE        Furniture
# 596      1597         Priya  FEMALE      -3   mumbai      Electronics
# 597      1598         Rahul  FEMALE  twenty     Pune      Electronics
# 598      1599         Kiran    MALE     NaN     PUNE         Clothing
# 599      1600         Kiran    MALE     120   Nagpur        Furniture
#
#      Quantity    Price Order_Date Payment_Method  Rating  Total_Amount  Month  \
# 1         4.0  67000.0 2024-04-13            UPI     2.0      268000.0      4
# 2         3.0      NaN 2024-03-18           Card     1.0           NaN      3
# 3         3.0  45000.0 2024-03-31            UPI     1.0      135000.0      3
# 4         4.0      NaN 2024-01-21           Card     3.0           NaN      1
# 5         5.0  45000.0 2024-01-21           cash     4.0      225000.0      1
# ..        ...      ...        ...            ...     ...           ...    ...
# 595       4.0   1500.0 2024-03-17           Card     5.0        6000.0      3
# 596       3.0    500.0 2024-04-18           Card     2.0        1500.0      4
# 597       3.0      NaN 2024-02-23           Card     1.0           NaN      2
# 598       1.0  25000.0 2024-03-10           Card     3.0       25000.0      3
# 599       2.0    500.0 2024-01-18           card     3.0        1000.0      1
#
#      Day
# 1     13
# 2     18
# 3     31
# 4     21
# 5     21
# ..   ...
# 595   17
# 596   18
# 597   23
# 598   10
# 599   18
#
# [575 rows x 14 columns]

# %%
df.to_csv("cleaned_sales.csv", index=False)

df=pd.read_csv("cleaned_sales.csv")
print(df)
# Out:
#      Order_ID Customer_Name  Gender   Age     City Product_Category  Quantity  \
# 0        1001           NaN  Female  22.0   mumbai       electronic       1.0
# 1        1003        Anjali    Male  21.0      NaN      Electronics       3.0
# 2        1005         Akash  Female  45.0      NaN        Furniture       4.0
# 3        1006         Pooja  Female  38.0   Nagpur         Clothing       5.0
# 4        1011         Vikas    Male  39.0   mumbai       electronic       3.0
# ..        ...           ...     ...   ...      ...              ...       ...
# 121      1003        Anjali    Male  21.0      NaN      Electronics       3.0
# 122      1005         Akash  Female  45.0      NaN        Furniture       4.0
# 123      1006         Pooja  Female  38.0   Nagpur         Clothing       5.0
# 124      1011         Vikas    Male  39.0   mumbai       electronic       3.0
# 125      1014         Kiran    Male  20.0   mumbai          Clothng       1.0
#
#      Price  Order_Date Payment_Method  Rating
# 0      abc  05-01-2024            UPI     1.0
# 1      NaN  18-03-2024           Card     1.0
# 2      NaN  21-01-2024           Card     3.0
# 3    45000  21-01-2024           cash     4.0
# 4      NaN  15-01-2024           Card     4.0
# ..     ...         ...            ...     ...
# 121    NaN  18-03-2024           Card     1.0
# 122    NaN  21-01-2024           Card     3.0
# 123  45000  21-01-2024           cash     4.0
# 124    NaN  15-01-2024           Card     4.0
# 125  25000  17-01-2024           cash     5.0
#
# [126 rows x 11 columns]

# %%
df['Total_Amount'].sum()
# Out:
# np.float64(201429325.0)

# %%
df.groupby('Product_Category')['Total_Amount'].sum().sort_values(ascending=False)
# Out:
# Product_Category
# Clothng        57425447.0
# electronic     52891953.0
# Electronics    38207465.0
# Furniture      27910978.0
# Clothing       24993482.0
# Name: Total_Amount, dtype: float64

# %%
df['Payment_Method'].value_counts()
# Out:
# Payment_Method
# UPI     124
# cash    124
# Card    116
# Cash    113
# card    112
# Name: count, dtype: int64

# %%
print(df["Sales"].sum())
# Out:
# 32812972.0

# %%
print(df["Sales"].mean())
# Out:
# 565740.8965517242

# %%
print(df["Sales"].max())
# Out:
# 3999996.0

# %%
monthly_sales = df.groupby("Month")["Sales"].sum()

monthly_sales.plot(kind="line")

plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales")

plt.show()

# %%
category_sales = df.groupby("Product_Category")["Sales"].sum()

category_sales.plot(kind="bar")

plt.title("Category Wise Sales")
plt.xlabel("Category")
plt.ylabel("Sales")

plt.show()

# %%
gender_sales = df.groupby("Gender")["Sales"].sum()

gender_sales.plot(kind="pie", autopct="%1.1f%%")

plt.title("Gender Wise Sales")

plt.show()

# %%
from sqlalchemy import create_engine

engine = create_engine("postgresql://postgres:#malti@localhost:5432/sales_db")
print("Database Connected Successfully!")
# Out:
# Database Connected Successfully!

# %%
df.to_sql("cleaned_sales_table", engine, if_exists="replace", index=False)
# Out:
# 126

# %%
df = pd.read_csv("cleaned_sales.csv")
df.head()
# Out:
#    Order_ID Customer_Name  Gender   Age     City Product_Category  Quantity  \
# 0      1001           NaN  Female  22.0   mumbai       electronic       1.0
# 1      1003        Anjali    Male  21.0      NaN      Electronics       3.0
# 2      1005         Akash  Female  45.0      NaN        Furniture       4.0
# 3      1006         Pooja  Female  38.0   Nagpur         Clothing       5.0
# 4      1011         Vikas    Male  39.0   mumbai       electronic       3.0
#
#    Price  Order_Date Payment_Method  Rating
# 0    abc  05-01-2024            UPI     1.0
# 1    NaN  18-03-2024           Card     1.0
# 2    NaN  21-01-2024           Card     3.0
# 3  45000  21-01-2024           cash     4.0
# 4    NaN  15-01-2024           Card     4.0
